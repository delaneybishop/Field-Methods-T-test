# %%
import pandas as pd
import os
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Delaney/Documents/Quality_Beaver_Meadows_Data_Template.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SampleID          36 non-null     object
#  1   Date              36 non-null     object
#  2   Time              36 non-null     object
#  3   Site_Information  36 non-null     object
#  4   Site_Location     36 non-null     object
#  5   Temp _C           36 non-null     float64
#  6   EC                36 non-null     float64
#  7   NOx_mgL           36 non-null     float64
#  8   PO4_mgL           36 non-null     float64
#  9   NH4               36 non-null     float64
#  10  Notes             23 non-null     object
#  11  Key               5 non-null      object
#  12  Dam Location      2 non-null      object
#  13  Unnamed: 13       2 non-null      object
# dtypes: float64(5), object(9)
# memory usage: 4.1+ KB

# %%
stats.ttest_ind(df['PO4_mgL'][df['Site_Location'] == 'Upper'],
                df['PO4_mgL'][df['Site_Location'] == 'Lower'])
# Out:
# Ttest_indResult(statistic=0.7560560249377335, pvalue=0.45482237068604225)

# %%
stats.ttest_ind(df['NOx_mgL'][df['Site_Location'] == 'Upper'],
                df['NOx_mgL'][df['Site_Location'] == 'Lower'])
# Out:
# Ttest_indResult(statistic=4.999923488320479, pvalue=1.718177025410876e-05)

# %%
stats.ttest_ind(df['NH4'][df['Site_Location'] == 'Upper'],
                df['NH4'][df['Site_Location'] == 'Lower'])
# Out:
# Ttest_indResult(statistic=-0.6458931135338328, pvalue=0.5226843428494168)

# %%
stats.ttest_ind(df['EC'][df['Site_Location'] == 'Upper'],
                df['EC'][df['Site_Location'] == 'Lower'])
# Out:
# Ttest_indResult(statistic=2.0862441169882655, pvalue=0.04452972858978828)

# %%
stats.ttest_ind(df['Temp _C'][df['Site_Location'] == 'Upper'],
                df['Temp _C'][df['Site_Location'] == 'Lower'])
# Out:
# Ttest_indResult(statistic=0.8160147867151681, pvalue=0.4201721047857664)

# %%
sampling_difference1 = df['PO4_mgL'][df['Site_Location'] == 'Upper'].values - \
                       df['PO4_mgL'][df['Site_Location'] == 'Lower'].values
                      
sampling_difference2 = df['NOx_mgL'][df['Site_Location'] == 'Upper'].values - \
                       df['NOx_mgL'][df['Site_Location'] == 'Lower'].values
                     
sampling_difference3 = df['NH4'][df['Site_Location'] == 'Upper'].values - \
                       df['NH4'][df['Site_Location'] == 'Lower'].values
                      
sampling_difference4 = df['EC'][df['Site_Location'] == 'Upper'].values - \
                       df['EC'][df['Site_Location'] == 'Lower'].values
                     
sampling_difference5 = df['Temp _C'][df['Site_Location'] == 'Upper'].values - \
                       df['Temp _C'][df['Site_Location'] == 'Lower'].values

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)
normality_plot, stat = stats.probplot(sampling_difference1, plot= plt, rvalue= True)
ax.set_title("Probability plot of PO4_mgL", fontsize= 20)
ax.set
plt.savefig('Probability plot of PO4_mgL')

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)
normality_plot, stat = stats.probplot(sampling_difference2, plot= plt, rvalue= True)
ax.set_title("Probability plot of NOx_mgL", fontsize= 20)
ax.set
plt.savefig('Probability plot of NOx_mgL')

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)
normality_plot, stat = stats.probplot(sampling_difference3, plot= plt, rvalue= True)
ax.set_title("Probability plot of NH4", fontsize= 20)
ax.set
plt.savefig('Probability plot of NH4')

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)
normality_plot, stat = stats.probplot(sampling_difference4, plot= plt, rvalue= True)
ax.set_title("Probability plot of EC", fontsize= 20)
ax.set
plt.savefig('Probability plot of EC')

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)
normality_plot, stat = stats.probplot(sampling_difference5, plot= plt, rvalue= True)
ax.set_title("Probability plot of Temp_C", fontsize= 20)
ax.set
plt.savefig('Probability plot of Temp_C')
